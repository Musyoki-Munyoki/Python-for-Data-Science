# %%
#importing the necessary libraries
import pandas as pd #for data handling
import numpy as np #for data manipulation
import matplotlib.pyplot as plt #for visualisation

# %%
data=pd.read_csv("pokemon_data.csv") #loading the dataset
data.head()#used to view thw first 5 rows of a dataset
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
data.info() #used to get the information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
data.isnull().sum()#used to check for missing values in the dataset
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
data["Type 2"].fillna("None", inplace=True)#filling the missing values in Type 2 column with None

# %%
data.isnull().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
data.rename(columns={"Type 1":"Primary Type","Sp. Atk":"SP_Attack"})
# Out:
#        #                   Name Primary Type  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur        Grass  Poison  45      49       49
# 1      2                Ivysaur        Grass  Poison  60      62       63
# 2      3               Venusaur        Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur        Grass  Poison  80     100      123
# 4      4             Charmander         Fire    None  39      52       43
# ..   ...                    ...          ...     ...  ..     ...      ...
# 795  719                Diancie         Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie         Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined      Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound      Psychic    Dark  80     160       60
# 799  721              Volcanion         Fire   Water  80     110      120
#
#      SP_Attack  Sp. Def  Speed  Generation  Legendary
# ...

# %%
plt.hist(data["HP"])
plt.title("Pokeman Hp Distribution")
plt.xlabel("HP")
# Out:
# Text(0.5, 0, 'HP')

# %%
data["Attack"].mean()
# Out:
# np.float64(79.00125)
